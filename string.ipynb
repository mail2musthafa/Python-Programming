# %%
# Pthon strng
# A string is the data strature in python that re present sequebxe of charectier

# %%
print("A Computer Science portal for geeks") 
print('A')
# Out:
# A Computer Science portal for geeks
# A

# %%
print("welome!")
# Out:
# welome!

# %%
a = "welcom to the string concepts22"
print(a)
# Out:
# welcom to the string concepts22

# %%
import numpy as np
import seaborn as sns
n = 1000
def norm_fun(n):
    x = np.random.randn(n)
    sns.histplot(x,bins = 10,kde = True)
b = norm_fun(n) 
print(b)
# Out:
# None
